# %% [markdown]
# # CAPSTONE PROJECT
# ## Phase 2: Data Understanding & Preparation
# ### Data Ingestion & Wrangling
# SALIFOU SYLLA
#
# OCTOBER 7, 2020

# %% [markdown]
# # Crash Reporting from dataMontgomery

# %% [markdown]
# The dataset used is Crash Reporting Data set. Those datasets are about car crashes that have occurred in the Montgomery County, they provide information about the driver, the incident, and the non-motorist. They are from https://www.montgomerycountymd.gov/. The dataMontgomery program seeks to provide residents and constituents with direct access to County datasets in consumable formats, so they may be viewed, sorted and used in various ways, including being potentially leveraged in the development of new applications and services by interested parties. Providing this information offers the public an opportunity to review and analyze raw data, and the opportunity to use it for a variety of purposes. The following are those three datasets:
# 1.	Crash Reporting - Incidents Data:
# https://data.montgomerycountymd.gov/Public-Safety/Crash-Reporting-Incidents-Data/bhju-22kf
# 2.	Crash Reporting - Drivers Data
# https://data.montgomerycountymd.gov/Public-Safety/Crash-Reporting-Drivers-Data/mmzv-x632
# 3.	Crash Reporting - Non-Motorists Data
# https://data.montgomerycountymd.gov/Public-Safety/Crash-Reporting-Non-Motorists-Data/n7fkdce5

# %% [markdown]
# ## Loading data file to pandas dataframe

# %%
# Importing libraries
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('Crash_Reporting_-_Incidents_Data.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65031 entries, 0 to 65030
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Report Number                 65031 non-null  object
#  1   Local Case Number             65031 non-null  object
#  2   Agency Name                   65031 non-null  object
#  3   ACRS Report Type              65031 non-null  object
#  4   Crash Date/Time               65031 non-null  object
#  5   Hit/Run                       65029 non-null  object
#  6   Route Type                    56369 non-null  object
#  7   Mile Point                    56724 non-null  float64
#  8   Mile Point Direction          56381 non-null  object
#  9   Lane Direction                56735 non-null  object
#  10  Lane Number                   65031 non-null  int64
#  11  Lane Type                     6277 non-null   object
#  12  Number of Lanes               65031 non-null  int64
#  13  Direction                     56724 non-null  object
#  14  Distance                      58590 non-null  float64
#  15  Distance Unit                 56734 non-null  object
#  16  Road Grade                    56275 non-null  object
#  17  NonTraffic                    65031 non-null  object
#  18  Road Name                     56734 non-null  object
#  19  Cross-Street Type             56358 non-null  object
#  20  Cross-Street Name             56730 non-null  object
#  21  Off-Road Description          8296 non-null   object
#  22  Municipality                  6865 non-null   object
#  23  Related Non-Motorist          3558 non-null   object
#  24  At Fault                      65031 non-null  object
#  25  Collision Type                64703 non-null  object
#  26  Weather                       59548 non-null  object
#  27  Surface Condition             55057 non-null  object
#  28  Light                         64497 non-null  object
#  29  Traffic Control               53277 non-null  object
#  30  Driver Substance Abuse        54563 non-null  object
#  31  Non-Motorist Substance Abuse  2823 non-null   object
#  32  First Harmful Event           64675 non-null  object
#  33  Second Harmful Event          16195 non-null  object
#  34  Fixed Oject Struck            13450 non-null  object
#  35  Junction                      47750 non-null  object
#  36  Intersection Type             31864 non-null  object
#  37  Intersection Area             18354 non-null  object
#  38  Road Alignment                56443 non-null  object
#  39  Road Condition                54281 non-null  object
#  40  Road Division                 55867 non-null  object
#  41  Latitude                      65031 non-null  float64
#  42  Longitude                     65031 non-null  float64
#  43  Location                      65031 non-null  object
# dtypes: float64(4), int64(2), object(38)
# memory usage: 21.8+ MB

# %%
# remove spaces in columns name
df1.columns = df1.columns.str.replace(' ','_').str.lower().str.replace('/','_').str.replace('-','_')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65031 entries, 0 to 65030
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   report_number                 65031 non-null  object
#  1   local_case_number             65031 non-null  object
#  2   agency_name                   65031 non-null  object
#  3   acrs_report_type              65031 non-null  object
#  4   crash_date_time               65031 non-null  object
#  5   hit_run                       65029 non-null  object
#  6   route_type                    56369 non-null  object
#  7   mile_point                    56724 non-null  float64
#  8   mile_point_direction          56381 non-null  object
#  9   lane_direction                56735 non-null  object
#  10  lane_number                   65031 non-null  int64
#  11  lane_type                     6277 non-null   object
#  12  number_of_lanes               65031 non-null  int64
#  13  direction                     56724 non-null  object
#  14  distance                      58590 non-null  float64
#  15  distance_unit                 56734 non-null  object
#  16  road_grade                    56275 non-null  object
#  17  nontraffic                    65031 non-null  object
#  18  road_name                     56734 non-null  object
#  19  cross_street_type             56358 non-null  object
#  20  cross_street_name             56730 non-null  object
#  21  off_road_description          8296 non-null   object
#  22  municipality                  6865 non-null   object
#  23  related_non_motorist          3558 non-null   object
#  24  at_fault                      65031 non-null  object
#  25  collision_type                64703 non-null  object
#  26  weather                       59548 non-null  object
#  27  surface_condition             55057 non-null  object
#  28  light                         64497 non-null  object
#  29  traffic_control               53277 non-null  object
#  30  driver_substance_abuse        54563 non-null  object
#  31  non_motorist_substance_abuse  2823 non-null   object
#  32  first_harmful_event           64675 non-null  object
#  33  second_harmful_event          16195 non-null  object
#  34  fixed_oject_struck            13450 non-null  object
#  35  junction                      47750 non-null  object
#  36  intersection_type             31864 non-null  object
#  37  intersection_area             18354 non-null  object
#  38  road_alignment                56443 non-null  object
#  39  road_condition                54281 non-null  object
#  40  road_division                 55867 non-null  object
#  41  latitude                      65031 non-null  float64
#  42  longitude                     65031 non-null  float64
#  43  location                      65031 non-null  object
# dtypes: float64(4), int64(2), object(38)
# memory usage: 21.8+ MB

# %%
df2 = pd.read_csv('Crash_Reporting_-_Drivers_Data.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115558 entries, 0 to 115557
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Report Number                   115558 non-null  object
#  1   Local Case Number               115558 non-null  object
#  2   Agency Name                     115558 non-null  object
#  3   ACRS Report Type                115558 non-null  object
#  4   Crash Date/Time                 115558 non-null  object
#  5   Route Type                      104355 non-null  object
#  6   Road Name                       104918 non-null  object
#  7   Cross-Street Type               104341 non-null  object
#  8   Cross-Street Name               104914 non-null  object
#  9   Off-Road Description            10639 non-null   object
#  10  Municipality                    12589 non-null   object
#  11  Related Non-Motorist            3597 non-null    object
#  12  Collision Type                  115175 non-null  object
#  13  Weather                         106418 non-null  object
#  14  Surface Condition               101869 non-null  object
#  15  Light                           114603 non-null  object
#  16  Traffic Control                 97211 non-null   object
#  17  Driver Substance Abuse          94391 non-null   object
#  18  Non-Motorist Substance Abuse    2847 non-null    object
#  19  Person ID                       115558 non-null  object
#  20  Driver At Fault                 115558 non-null  object
#  21  Injury Severity                 115558 non-null  object
#  22  Circumstance                    22376 non-null   object
#  23  Driver Distracted By            115558 non-null  object
#  24  Drivers License State           110022 non-null  object
#  25  Vehicle ID                      115558 non-null  object
#  26  Vehicle Damage Extent           115352 non-null  object
#  27  Vehicle First Impact Location   115402 non-null  object
#  28  Vehicle Second Impact Location  115302 non-null  object
#  29  Vehicle Body Type               113895 non-null  object
#  30  Vehicle Movement                115321 non-null  object
#  31  Vehicle Continuing Dir          113843 non-null  object
#  32  Vehicle Going Dir               113843 non-null  object
#  33  Speed Limit                     115558 non-null  int64
#  34  Driverless Vehicle              115558 non-null  object
#  35  Parked Vehicle                  115558 non-null  object
#  36  Vehicle Year                    115558 non-null  int64
#  37  Vehicle Make                    115537 non-null  object
#  38  Vehicle Model                   115506 non-null  object
#  39  Equipment Problems              89958 non-null   object
#  40  Latitude                        115558 non-null  float64
#  41  Longitude                       115558 non-null  float64
#  42  Location                        115558 non-null  object
# dtypes: float64(2), int64(2), object(39)
# memory usage: 37.9+ MB

# %%
# remove spaces in columns name
df2.columns = df2.columns.str.replace(' ','_').str.lower().str.replace('/','_').str.replace('-','_')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115558 entries, 0 to 115557
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   report_number                   115558 non-null  object
#  1   local_case_number               115558 non-null  object
#  2   agency_name                     115558 non-null  object
#  3   acrs_report_type                115558 non-null  object
#  4   crash_date_time                 115558 non-null  object
#  5   route_type                      104355 non-null  object
#  6   road_name                       104918 non-null  object
#  7   cross_street_type               104341 non-null  object
#  8   cross_street_name               104914 non-null  object
#  9   off_road_description            10639 non-null   object
#  10  municipality                    12589 non-null   object
#  11  related_non_motorist            3597 non-null    object
#  12  collision_type                  115175 non-null  object
#  13  weather                         106418 non-null  object
#  14  surface_condition               101869 non-null  object
#  15  light                           114603 non-null  object
#  16  traffic_control                 97211 non-null   object
#  17  driver_substance_abuse          94391 non-null   object
#  18  non_motorist_substance_abuse    2847 non-null    object
#  19  person_id                       115558 non-null  object
#  20  driver_at_fault                 115558 non-null  object
#  21  injury_severity                 115558 non-null  object
#  22  circumstance                    22376 non-null   object
#  23  driver_distracted_by            115558 non-null  object
#  24  drivers_license_state           110022 non-null  object
#  25  vehicle_id                      115558 non-null  object
#  26  vehicle_damage_extent           115352 non-null  object
#  27  vehicle_first_impact_location   115402 non-null  object
#  28  vehicle_second_impact_location  115302 non-null  object
#  29  vehicle_body_type               113895 non-null  object
#  30  vehicle_movement                115321 non-null  object
#  31  vehicle_continuing_dir          113843 non-null  object
#  32  vehicle_going_dir               113843 non-null  object
#  33  speed_limit                     115558 non-null  int64
#  34  driverless_vehicle              115558 non-null  object
#  35  parked_vehicle                  115558 non-null  object
#  36  vehicle_year                    115558 non-null  int64
#  37  vehicle_make                    115537 non-null  object
#  38  vehicle_model                   115506 non-null  object
#  39  equipment_problems              89958 non-null   object
#  40  latitude                        115558 non-null  float64
#  41  longitude                       115558 non-null  float64
#  42  location                        115558 non-null  object
# dtypes: float64(2), int64(2), object(39)
# memory usage: 37.9+ MB

# %%
df3 = pd.read_csv('Crash_Reporting_-_Non-Motorists_Data.csv')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3738 entries, 0 to 3737
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Report Number                     3738 non-null   object
#  1   Local Case Number                 3738 non-null   int64
#  2   Agency Name                       3738 non-null   object
#  3   ACRS Report Type                  3738 non-null   object
#  4   Crash Date/Time                   3738 non-null   object
#  5   Route Type                        2858 non-null   object
#  6   Road Name                         2903 non-null   object
#  7   Cross-Street Type                 2858 non-null   object
#  8   Cross-Street Name                 2902 non-null   object
#  9   Off-Road Description              835 non-null    object
#  10  Municipality                      410 non-null    object
#  11  Related Non-Motorist              3738 non-null   object
#  12  Collision Type                    3622 non-null   object
#  13  Weather                           3395 non-null   object
#  14  Surface Condition                 2792 non-null   object
#  15  Light                             3707 non-null   object
#  16  Traffic Control                   3154 non-null   object
#  17  Driver Substance Abuse            3038 non-null   object
#  18  Non-Motorist Substance Abuse      2950 non-null   object
#  19  Person ID                         3738 non-null   object
#  20  Pedestrian Type                   3738 non-null   object
#  21  Pedestrian Movement               3634 non-null   object
#  22  Pedestrian Actions                3535 non-null   object
#  23  Pedestrian Location               3630 non-null   object
#  24  Pedestrian Obeyed Traffic Signal  2617 non-null   object
#  25  Pedestrian Visibility             3381 non-null   object
#  26  At Fault                          3451 non-null   object
#  27  Injury Severity                   3738 non-null   object
#  28  Safety Equipment                  2388 non-null   object
#  29  Latitude                          3738 non-null   float64
#  30  Longitude                         3738 non-null   float64
#  31  Location                          3738 non-null   object
# dtypes: float64(2), int64(1), object(29)
# memory usage: 934.6+ KB

# %%
# remove spaces in columns name
df3.columns = df3.columns.str.replace(' ','_').str.lower().str.replace('/','_').str.replace('-','_')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3738 entries, 0 to 3737
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   report_number                     3738 non-null   object
#  1   local_case_number                 3738 non-null   int64
#  2   agency_name                       3738 non-null   object
#  3   acrs_report_type                  3738 non-null   object
#  4   crash_date_time                   3738 non-null   object
#  5   route_type                        2858 non-null   object
#  6   road_name                         2903 non-null   object
#  7   cross_street_type                 2858 non-null   object
#  8   cross_street_name                 2902 non-null   object
#  9   off_road_description              835 non-null    object
#  10  municipality                      410 non-null    object
#  11  related_non_motorist              3738 non-null   object
#  12  collision_type                    3622 non-null   object
#  13  weather                           3395 non-null   object
#  14  surface_condition                 2792 non-null   object
#  15  light                             3707 non-null   object
#  16  traffic_control                   3154 non-null   object
#  17  driver_substance_abuse            3038 non-null   object
#  18  non_motorist_substance_abuse      2950 non-null   object
#  19  person_id                         3738 non-null   object
#  20  pedestrian_type                   3738 non-null   object
#  21  pedestrian_movement               3634 non-null   object
#  22  pedestrian_actions                3535 non-null   object
#  23  pedestrian_location               3630 non-null   object
#  24  pedestrian_obeyed_traffic_signal  2617 non-null   object
#  25  pedestrian_visibility             3381 non-null   object
#  26  at_fault                          3451 non-null   object
#  27  injury_severity                   3738 non-null   object
#  28  safety_equipment                  2388 non-null   object
#  29  latitude                          3738 non-null   float64
#  30  longitude                         3738 non-null   float64
#  31  location                          3738 non-null   object
# dtypes: float64(2), int64(1), object(29)
# memory usage: 934.6+ KB

# %% [markdown]
# # Combining DataFrames with Pandas
# ## Combine three DataFrames using a unique ID found in those DataFrames

# %% [markdown]
# ### Identifying join keys
# To identify appropriate join keys we first need to know which field(s) are shared between the three files (DataFrames). We might inspect all three DataFrames to identify these columns. If we are lucky, the three DataFrames will have columns with the same name that also contain the same data. If we are less lucky, we need to identify a (differently-named) column in each DataFrame that contains the same information.

# %%
df1.columns
# Out:
# Index(['report_number', 'local_case_number', 'agency_name', 'acrs_report_type',
#        'crash_date_time', 'hit_run', 'route_type', 'mile_point',
#        'mile_point_direction', 'lane_direction', 'lane_number', 'lane_type',
#        'number_of_lanes', 'direction', 'distance', 'distance_unit',
#        'road_grade', 'nontraffic', 'road_name', 'cross_street_type',
#        'cross_street_name', 'off_road_description', 'municipality',
#        'related_non_motorist', 'at_fault', 'collision_type', 'weather',
#        'surface_condition', 'light', 'traffic_control',
#        'driver_substance_abuse', 'non_motorist_substance_abuse',
#        'first_harmful_event', 'second_harmful_event', 'fixed_oject_struck',
#        'junction', 'intersection_type', 'intersection_area', 'road_alignment',
#        'road_condition', 'road_division', 'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['report_number', 'local_case_number', 'agency_name', 'acrs_report_type',
#        'crash_date_time', 'route_type', 'road_name', 'cross_street_type',
#        'cross_street_name', 'off_road_description', 'municipality',
#        'related_non_motorist', 'collision_type', 'weather',
#        'surface_condition', 'light', 'traffic_control',
#        'driver_substance_abuse', 'non_motorist_substance_abuse', 'person_id',
#        'driver_at_fault', 'injury_severity', 'circumstance',
#        'driver_distracted_by', 'drivers_license_state', 'vehicle_id',
#        'vehicle_damage_extent', 'vehicle_first_impact_location',
#        'vehicle_second_impact_location', 'vehicle_body_type',
#        'vehicle_movement', 'vehicle_continuing_dir', 'vehicle_going_dir',
#        'speed_limit', 'driverless_vehicle', 'parked_vehicle', 'vehicle_year',
#        'vehicle_make', 'vehicle_model', 'equipment_problems', 'latitude',
#        'longitude', 'location'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['report_number', 'local_case_number', 'agency_name', 'acrs_report_type',
#        'crash_date_time', 'route_type', 'road_name', 'cross_street_type',
#        'cross_street_name', 'off_road_description', 'municipality',
#        'related_non_motorist', 'collision_type', 'weather',
#        'surface_condition', 'light', 'traffic_control',
#        'driver_substance_abuse', 'non_motorist_substance_abuse', 'person_id',
#        'pedestrian_type', 'pedestrian_movement', 'pedestrian_actions',
#        'pedestrian_location', 'pedestrian_obeyed_traffic_signal',
#        'pedestrian_visibility', 'at_fault', 'injury_severity',
#        'safety_equipment', 'latitude', 'longitude', 'location'],
#       dtype='object')

# %% [markdown]
# The report number or ACRS Report Number (report_number) assigned to the incident is a common key identifier.

# %% [markdown]
# Now that we know the fields with the common incidents ID attributes in each DataFrame, we are almost ready to join our data. However, since there are different types of joins, we also need to decide which type of join makes sense for our analysis.

# %% [markdown]
# # Left joins
# What if we want to add information from Drivers data and Non-Motorists data to Incidents data without losing any of the information from Incidents? In this case, we use a different type of join called a “left outer join”, or a “left join”.
# a left join will return all of the rows from the left DataFrame, even those rows whose join key(s) do not have values in the right DataFrame. Rows in the left DataFrame that are missing values for the join key(s) in the right DataFrame will simply have null (i.e., NaN or None) values for those columns in the resulting joined DataFrame.

# %% [markdown]
# Note: a left join will still discard rows from the right DataFrame that do not have values for the join key(s) in the left DataFrame.

# %%
#A left join is performed in pandas by calling the merge function, but using the how='left' argument:
#We will fist left join Drivers data to the Incidents data, then left join the Non-Motorists data to the sesult. 

merged_left1 = pd.merge(left=df1, right=df2, how='left', left_on='report_number', right_on='report_number')

merged_left1.shape
merged_left1
# Out:
#        report_number local_case_number_x             agency_name_x  \
# 0        MCP9365000Y           180008970  Montgomery County Police
# 1        MCP9365000Y           180008970  Montgomery County Police
# 2        MCP2651001R           170540696  Montgomery County Police
# 3        MCP2651001R           170540696  Montgomery County Police
# 4        MCP2970000J            15032933                MONTGOMERY
# ...              ...                 ...                       ...
# 115979   MCP24870013           190005033  Montgomery County Police
# 115980   MCP2866003G            17012511  Montgomery County Police
# 115981   MCP2181000X            16041925  Montgomery County Police
# 115982   MCP2847001J            16037706  Montgomery County Police
# 115983   MCP2847001J            16037706  Montgomery County Police
#
#            acrs_report_type_x       crash_date_time_x hit_run  \
# 0       Property Damage Crash  02/21/2018 09:42:00 AM      No
# 1       Property Damage Crash  02/21/2018 09:42:00 AM      No
# 2                Injury Crash  11/03/2017 02:40:00 PM      No
# 3                Injury Crash  11/03/2017 02:40:00 PM      No
# 4       Property Damage Crash  07/06/2015 03:30:00 AM      No
# ...                       ...                     ...     ...
# 115979  Property Damage Crash  02/01/2019 08:31:00 AM      No
# 115980           Injury Crash  03/09/2017 08:37:00 PM      No
# 115981  Property Damage Crash  08/18/2016 11:35:00 AM     Yes
# 115982  Property Damage Crash  07/25/2016 08:47:00 PM      No
# 115983  Property Damage Crash  07/25/2016 08:47:00 PM      No
#
#             route_type_x  mile_point mile_point_direction lane_direction  ...  \
# 0             US (State)      10.160                North          North  ...
# 1             US (State)      10.160                North          North  ...
# 2             US (State)       3.645                North          South  ...
# 3             US (State)       3.645                North          South  ...
# 4                    NaN         NaN                  NaN            NaN  ...
# ...                  ...         ...                  ...            ...  ...
# 115979      Municipality       2.950                 West           West  ...
# 115980            County       0.720                 East           West  ...
# 115981  Maryland (State)      14.640                 East           East  ...
# 115982  Maryland (State)       4.640                North          North  ...
# 115983  Maryland (State)       4.640                North          North  ...
#
#         speed_limit driverless_vehicle  parked_vehicle vehicle_year  \
# 0              55.0                 No              No       2007.0
# 1              55.0                 No              No       2016.0
# 2              40.0                 No              No       2014.0
# 3              40.0                 No              No       2009.0
# 4               5.0                 No              No       2014.0
# ...             ...                ...             ...          ...
# 115979         30.0                 No              No       2016.0
# 115980         35.0                 No              No       1999.0
# 115981         40.0                 No              No       2011.0
# 115982         45.0                 No              No       2005.0
# 115983         45.0                 No              No       1993.0
#
#         vehicle_make vehicle_model equipment_problems latitude_y longitude_y  \
# 0              VOLVO           S60          NO MISUSE  39.103107  -76.933651
# 1             TOYOTA          RAV4          NO MISUSE  39.103107  -76.933651
# 2               FORD            4D          NO MISUSE  39.031627  -77.004603
# 3              HONDA        SHADOW          NO MISUSE  39.031627  -77.004603
# 4              DODGE       CHARGER                NaN  39.039951  -77.052132
# ...              ...           ...                ...        ...         ...
# 115979          FORD            TK          NO MISUSE  39.072602  -77.181215
# 115980    OLDSMOBILE           4DR          NO MISUSE  39.105421  -76.990400
# 115981        NISSAN        ALTIMA          NO MISUSE  39.112097  -77.273705
# 115982           BMW            X3          NO MISUSE  39.057358  -77.049833
# 115983         WHITE        TOYOTA          NO MISUSE  39.057358  -77.049833
#
#                          location_y
# 0       (39.10310676, -76.93365097)
# 1       (39.10310676, -76.93365097)
# 2       (39.03162667, -77.00460333)
# 3       (39.03162667, -77.00460333)
# 4        (39.0399509, -77.05213219)
# ...                             ...
# 115979    (39.07260167, -77.181215)
# 115980  (39.10542067, -76.99039983)
# 115981    (39.11209667, -77.273705)
# 115982  (39.05735833, -77.04983333)
# 115983  (39.05735833, -77.04983333)
#
# [115984 rows x 86 columns]

# %%
merged_left2 = pd.merge(left=merged_left1, right=df3, how='left', left_on='report_number', right_on='report_number')

merged_left2.shape
merged_left2
# Out:
#        report_number local_case_number_x             agency_name_x  \
# 0        MCP9365000Y           180008970  Montgomery County Police
# 1        MCP9365000Y           180008970  Montgomery County Police
# 2        MCP2651001R           170540696  Montgomery County Police
# 3        MCP2651001R           170540696  Montgomery County Police
# 4        MCP2970000J            15032933                MONTGOMERY
# ...              ...                 ...                       ...
# 116167   MCP24870013           190005033  Montgomery County Police
# 116168   MCP2866003G            17012511  Montgomery County Police
# 116169   MCP2181000X            16041925  Montgomery County Police
# 116170   MCP2847001J            16037706  Montgomery County Police
# 116171   MCP2847001J            16037706  Montgomery County Police
#
#            acrs_report_type_x       crash_date_time_x hit_run  \
# 0       Property Damage Crash  02/21/2018 09:42:00 AM      No
# 1       Property Damage Crash  02/21/2018 09:42:00 AM      No
# 2                Injury Crash  11/03/2017 02:40:00 PM      No
# 3                Injury Crash  11/03/2017 02:40:00 PM      No
# 4       Property Damage Crash  07/06/2015 03:30:00 AM      No
# ...                       ...                     ...     ...
# 116167  Property Damage Crash  02/01/2019 08:31:00 AM      No
# 116168           Injury Crash  03/09/2017 08:37:00 PM      No
# 116169  Property Damage Crash  08/18/2016 11:35:00 AM     Yes
# 116170  Property Damage Crash  07/25/2016 08:47:00 PM      No
# 116171  Property Damage Crash  07/25/2016 08:47:00 PM      No
#
#             route_type_x  mile_point mile_point_direction lane_direction  ...  \
# 0             US (State)      10.160                North          North  ...
# 1             US (State)      10.160                North          North  ...
# 2             US (State)       3.645                North          South  ...
# 3             US (State)       3.645                North          South  ...
# 4                    NaN         NaN                  NaN            NaN  ...
# ...                  ...         ...                  ...            ...  ...
# 116167      Municipality       2.950                 West           West  ...
# 116168            County       0.720                 East           West  ...
# 116169  Maryland (State)      14.640                 East           East  ...
# 116170  Maryland (State)       4.640                North          North  ...
# 116171  Maryland (State)       4.640                North          North  ...
#
#         pedestrian_actions pedestrian_location  \
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ...                    ...                 ...
# 116167                 NaN                 NaN
# 116168                 NaN                 NaN
# 116169                 NaN                 NaN
# 116170                 NaN                 NaN
# 116171                 NaN                 NaN
#
#         pedestrian_obeyed_traffic_signal pedestrian_visibility  at_fault_y  \
# 0                                    NaN                   NaN         NaN
# 1                                    NaN                   NaN         NaN
# 2                                    NaN                   NaN         NaN
# 3                                    NaN                   NaN         NaN
# 4                                    NaN                   NaN         NaN
# ...                                  ...                   ...         ...
# 116167                               NaN                   NaN         NaN
# 116168                               NaN                   NaN         NaN
# 116169                               NaN                   NaN         NaN
# 116170                               NaN                   NaN         NaN
# 116171                               NaN                   NaN         NaN
#
#        injury_severity_y safety_equipment latitude longitude location
# 0                    NaN              NaN      NaN       NaN      NaN
# 1                    NaN              NaN      NaN       NaN      NaN
# 2                    NaN              NaN      NaN       NaN      NaN
# 3                    NaN              NaN      NaN       NaN      NaN
# 4                    NaN              NaN      NaN       NaN      NaN
# ...                  ...              ...      ...       ...      ...
# 116167               NaN              NaN      NaN       NaN      NaN
# 116168               NaN              NaN      NaN       NaN      NaN
# 116169               NaN              NaN      NaN       NaN      NaN
# 116170               NaN              NaN      NaN       NaN      NaN
# 116171               NaN              NaN      NaN       NaN      NaN
#
# [116172 rows x 117 columns]

# %%
merged_left2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116172 entries, 0 to 116171
# Columns: 117 entries, report_number to location
# dtypes: float64(11), int64(2), object(104)
# memory usage: 104.6+ MB

# %% [markdown]
# # Inner joins
# The most common type of join is called an inner join. An inner join combines two DataFrames based on a join key and returns a new DataFrame that contains only those rows that have matching values in both of the original DataFrames.
#
# Inner joins yield a DataFrame that contains only rows where the value being joined exists in BOTH datasets.
#
# The pandas function for performing joins is called merge and an Inner join is the default option:

# %%
# In this case `acrs_report_type` is the only column name in  the three dataframes, so if we skipped `left_on`
# And `right_on` arguments we would still get the same result

merged_inner1 = pd.merge(left=df1, right=df2, left_on='report_number', right_on='report_number')

# What's the size of the output data?
merged_inner1.shape
merged_inner1
# Out:
#        report_number local_case_number_x             agency_name_x  \
# 0        MCP9365000Y           180008970  Montgomery County Police
# 1        MCP9365000Y           180008970  Montgomery County Police
# 2        MCP2651001R           170540696  Montgomery County Police
# 3        MCP2651001R           170540696  Montgomery County Police
# 4        MCP2970000J            15032933                MONTGOMERY
# ...              ...                 ...                       ...
# 115553   MCP24870013           190005033  Montgomery County Police
# 115554   MCP2866003G            17012511  Montgomery County Police
# 115555   MCP2181000X            16041925  Montgomery County Police
# 115556   MCP2847001J            16037706  Montgomery County Police
# 115557   MCP2847001J            16037706  Montgomery County Police
#
#            acrs_report_type_x       crash_date_time_x hit_run  \
# 0       Property Damage Crash  02/21/2018 09:42:00 AM      No
# 1       Property Damage Crash  02/21/2018 09:42:00 AM      No
# 2                Injury Crash  11/03/2017 02:40:00 PM      No
# 3                Injury Crash  11/03/2017 02:40:00 PM      No
# 4       Property Damage Crash  07/06/2015 03:30:00 AM      No
# ...                       ...                     ...     ...
# 115553  Property Damage Crash  02/01/2019 08:31:00 AM      No
# 115554           Injury Crash  03/09/2017 08:37:00 PM      No
# 115555  Property Damage Crash  08/18/2016 11:35:00 AM     Yes
# 115556  Property Damage Crash  07/25/2016 08:47:00 PM      No
# 115557  Property Damage Crash  07/25/2016 08:47:00 PM      No
#
#             route_type_x  mile_point mile_point_direction lane_direction  ...  \
# 0             US (State)      10.160                North          North  ...
# 1             US (State)      10.160                North          North  ...
# 2             US (State)       3.645                North          South  ...
# 3             US (State)       3.645                North          South  ...
# 4                    NaN         NaN                  NaN            NaN  ...
# ...                  ...         ...                  ...            ...  ...
# 115553      Municipality       2.950                 West           West  ...
# 115554            County       0.720                 East           West  ...
# 115555  Maryland (State)      14.640                 East           East  ...
# 115556  Maryland (State)       4.640                North          North  ...
# 115557  Maryland (State)       4.640                North          North  ...
#
#         speed_limit driverless_vehicle  parked_vehicle vehicle_year  \
# 0                55                 No              No         2007
# 1                55                 No              No         2016
# 2                40                 No              No         2014
# 3                40                 No              No         2009
# 4                 5                 No              No         2014
# ...             ...                ...             ...          ...
# 115553           30                 No              No         2016
# 115554           35                 No              No         1999
# 115555           40                 No              No         2011
# 115556           45                 No              No         2005
# 115557           45                 No              No         1993
#
#         vehicle_make vehicle_model equipment_problems latitude_y longitude_y  \
# 0              VOLVO           S60          NO MISUSE  39.103107  -76.933651
# 1             TOYOTA          RAV4          NO MISUSE  39.103107  -76.933651
# 2               FORD            4D          NO MISUSE  39.031627  -77.004603
# 3              HONDA        SHADOW          NO MISUSE  39.031627  -77.004603
# 4              DODGE       CHARGER                NaN  39.039951  -77.052132
# ...              ...           ...                ...        ...         ...
# 115553          FORD            TK          NO MISUSE  39.072602  -77.181215
# 115554    OLDSMOBILE           4DR          NO MISUSE  39.105421  -76.990400
# 115555        NISSAN        ALTIMA          NO MISUSE  39.112097  -77.273705
# 115556           BMW            X3          NO MISUSE  39.057358  -77.049833
# 115557         WHITE        TOYOTA          NO MISUSE  39.057358  -77.049833
#
#                          location_y
# 0       (39.10310676, -76.93365097)
# 1       (39.10310676, -76.93365097)
# 2       (39.03162667, -77.00460333)
# 3       (39.03162667, -77.00460333)
# 4        (39.0399509, -77.05213219)
# ...                             ...
# 115553    (39.07260167, -77.181215)
# 115554  (39.10542067, -76.99039983)
# 115555    (39.11209667, -77.273705)
# 115556  (39.05735833, -77.04983333)
# 115557  (39.05735833, -77.04983333)
#
# [115558 rows x 86 columns]

# %%
merged_inner2 = pd.merge(left=merged_inner1, right=df3, left_on='report_number', right_on='report_number')

# What's the size of the output data?
merged_inner2.shape
merged_inner2
# Out:
#      report_number local_case_number_x             agency_name_x  \
# 0      MCP11210044           180029562  Montgomery County Police
# 1      MCP2885002V           180051502  Montgomery County Police
# 2      MCP2565005G           180031935  Montgomery County Police
# 3      MCP29690019            15062641                MONTGOMERY
# 4      MCP2353003K            17005729  Montgomery County Police
# ...            ...                 ...                       ...
# 3771   MCP30390024           180015700  Montgomery County Police
# 3772   MCP2717003Z            15059859                MONTGOMERY
# 3773   MCP3140000W           190006174  Montgomery County Police
# 3774   MCP1565003C           190007165  Montgomery County Police
# 3775   MCP2831001K            16053095  Montgomery County Police
#
#      acrs_report_type_x       crash_date_time_x hit_run      route_type_x  \
# 0          Injury Crash  06/15/2018 12:44:00 PM      No  Maryland (State)
# 1          Injury Crash  10/14/2018 09:40:00 PM     Yes               NaN
# 2          Injury Crash  06/28/2018 08:00:00 PM      No  Maryland (State)
# 3          Injury Crash  12/08/2015 10:30:00 AM     Yes            County
# 4          Injury Crash  02/02/2017 09:01:00 AM      No  Maryland (State)
# ...                 ...                     ...     ...               ...
# 3771       Injury Crash  03/31/2018 08:35:00 PM     Yes      Municipality
# 3772       Injury Crash  11/23/2015 12:45:00 PM      No  Maryland (State)
# 3773       Injury Crash  02/07/2019 10:12:00 PM      No               NaN
# 3774       Injury Crash  02/14/2019 06:31:00 AM      No            County
# 3775       Injury Crash  10/15/2016 08:26:00 PM      No               NaN
#
#       mile_point mile_point_direction lane_direction  ...  \
# 0          16.28                North          North  ...
# 1            NaN                  NaN            NaN  ...
# 2           5.97                North          North  ...
# 3           0.57                South          North  ...
# 4           3.37                North          South  ...
# ...          ...                  ...            ...  ...
# 3771        0.36                 West           West  ...
# 3772        2.92                 East           East  ...
# 3773         NaN                  NaN            NaN  ...
# 3774        0.67                South          North  ...
# 3775        0.00                  NaN          South  ...
#
#                  pedestrian_actions               pedestrian_location  \
# 0               NO IMPROPER ACTIONS           ON ROADWAY AT CROSSWALK
# 1               NO IMPROPER ACTIONS                             OTHER
# 2             IN ROADWAY IMPROPERLY       ON ROADWAY NOT AT CROSSWALK
# 3               NO IMPROPER ACTIONS           ON ROADWAY AT CROSSWALK
# 4     FAILURE TO YIELD RIGHT OF WAY  AT INTERSECTION BUT NO CROSSWALK
# ...                             ...                               ...
# 3771            NO IMPROPER ACTIONS           ON ROADWAY AT CROSSWALK
# 3772            NO IMPROPER ACTIONS           ON ROADWAY AT CROSSWALK
# 3773            NO IMPROPER ACTIONS                             OTHER
# 3774            NO IMPROPER ACTIONS           ON ROADWAY AT CROSSWALK
# 3775                      DART DASH       ON ROADWAY NOT AT CROSSWALK
#
#       pedestrian_obeyed_traffic_signal pedestrian_visibility  at_fault_y  \
# 0                   OBEYED PED. SIGNAL        MIXED CLOTHING          No
# 1                                  NaN        MIXED CLOTHING          No
# 2                   OBEYED PED. SIGNAL        LIGHT CLOTHING         Yes
# 3                       NO PED. SIGNAL        MIXED CLOTHING          No
# 4                       NO PED. SIGNAL        MIXED CLOTHING         Yes
# ...                                ...                   ...         ...
# 3771                    NO PED. SIGNAL        LIGHT CLOTHING          No
# 3772                OBEYED PED. SIGNAL        MIXED CLOTHING          No
# 3773                               NaN         DARK CLOTHING          No
# 3774                OBEYED PED. SIGNAL         DARK CLOTHING          No
# 3775                    NO PED. SIGNAL         DARK CLOTHING         Yes
#
#              injury_severity_y safety_equipment   latitude  longitude  \
# 0              POSSIBLE INJURY             NONE  39.161517 -77.222677
# 1       SUSPECTED MINOR INJURY             NONE  39.038410 -77.028740
# 2              POSSIBLE INJURY             NONE  38.978163 -77.098717
# 3       SUSPECTED MINOR INJURY             NONE  39.039457 -77.048553
# 4              POSSIBLE INJURY   MC/BIKE HELMET  39.008502 -77.098028
# ...                        ...              ...        ...        ...
# 3771           POSSIBLE INJURY             NONE  39.027937 -77.077920
# 3772    SUSPECTED MINOR INJURY              NaN  38.994387 -77.044267
# 3773           POSSIBLE INJURY              NaN  39.030202 -77.163412
# 3774  SUSPECTED SERIOUS INJURY              NaN  39.079090 -77.087397
# 3775           POSSIBLE INJURY             NONE  39.176718 -77.258507
#
#                          location
# 0     (39.16151667, -77.22267667)
# 1           (39.03841, -77.02874)
# 2     (38.97816333, -77.09871667)
# 3     (39.03945667, -77.04855333)
# 4     (39.00850167, -77.09802833)
# ...                           ...
# 3771     (39.02793667, -77.07792)
# 3772  (38.99438667, -77.04426667)
# 3773  (39.03020159, -77.16341202)
# 3774     (39.07909, -77.08739667)
# 3775  (39.17671833, -77.25850667)
#
# [3776 rows x 117 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Detecting Missing Values
# ### Standard Missing Values
# Pandas will recognize both empty cells and “NA” types as missing values. Let’s see how Pandas deals with these values

# %%
# Looking at the ST_NUM column
print (merged_left1['route_type_x'])
print (merged_left1['route_type_x'].isnull())
# Out:
# 0                 County
# 1                 County
# 2       Maryland (State)
# 3       Maryland (State)
# 4       Maryland (State)
#               ...
# 1401              County
# 1402              County
# 1403              County
# 1404              County
# 1405              County
# Name: route_type_x, Length: 1406, dtype: object
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1401    False
# 1402    False
# 1403    False
# 1404    False
# 1405    False
# Name: route_type_x, Length: 1406, dtype: bool

# %% [markdown]
# Taking a look at the column, we can see that Pandas filled in the blank space with “NA”. Using the isnull() method, we can confirm that both the missing value and “NA” were recognized as missing values. Both boolean responses are True.
# This is a simple example, but highlights an important point. Pandas will recognize both empty cells and “NA” types as missing values. In the next section, we’ll take a look at some types that Pandas won’t recognize.

# %% [markdown]
# ### Non-Standard Missing Values
# Sometimes it might be the case where there’s missing values that have different formats.

# %% [markdown]
# ### Unexpected Missing Values
# For example, if our feature is expected to be a string, but there’s a numeric type, then technically this is also a missing value.

# %% [markdown]
# ## Handling Missing Values
# Figuring out how to handle missing values.
# Sometimes we will simply want to delete those rows, other times we willll replace them.
# This shouldn’t be taken lightly.
# A very common way to replace missing values is using a median.
